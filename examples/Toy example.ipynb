# %%
import caspo_control
from colomoto.minibn import BooleanNetwork
# Out:
# This notebook has been executed using the docker image `algorecell/algorecell-docker` built on `2019-11-28`

# %%
bn = BooleanNetwork({
    "a": "a",
    "b": "a&c",
    "c": "a|!b",
    "d": "c"
})

# %%
s = caspo_control.reprogramming_to_attractor(bn, d=0, fixed={"a": 0}, exclude_goal=True)
s
# Out:
# [FromAny(PermanentPerturbation(b=1)), FromAny(PermanentPerturbation(c=0))]

# %%
s.as_graph()
